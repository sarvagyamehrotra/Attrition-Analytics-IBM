# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Sarva\\Desktop\\attririon_app\\notebooks'

# %%
import pandas as pd
import joblib

data = pd.read_csv("Attrition_Data.csv")
final_pipeline = joblib.load("../models/attrition_xgb_model.pkl")
X_full = data.drop(columns=["Attrition"])
y_full = data["Attrition"]
pred_probs = final_pipeline.predict_proba(X_full)[:, 1]
data["Pred_Attrition_Prob"] = pred_probs
data.to_csv("../data/attrition_scores.csv", index=False)
print("Saved attrition_scored.csv")
# Out:
# Saved attrition_scored.csv
